# %%
# Set project's environment variables
import os
import sys
from dotenv import load_dotenv
load_dotenv(dotenv_path="../project.env")
sys.path.append(os.environ["PYTHONPATH"])

import warnings
warnings.filterwarnings(
    "ignore",
    message=".*",
    category=UserWarning
)

# %%
import superheader as sup
import torch
import torch.nn as nn
import torch.optim as optim
import TRAIN.architecture.BERT.bert as bert
import live
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750712113.559055 11983514 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M3 Pro
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1750712113.570632 11983769 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1750712113.579324 11983769 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1750712113.583367 11983514 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M3 Pro
# W0000 00:00:1750712113.675492 11983777 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1750712113.686922 11983777 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
inference_config = {
  "TRAIN_classes" : 'all-classes',
  "data_unit" : sup.DATA_S_PV,
  "PH2" : False,
  "PH3" : True
}

# %%
live.classify_webcam_image(inference_config)
# Out:
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
# bad frame
