# %% [markdown]
# # Context
# This notebook drives the training process for different models.

# %%
# Set project's environment variables
import os
import sys
from dotenv import load_dotenv
load_dotenv(dotenv_path="../../../project.env")
sys.path.append(os.environ["PYTHONPATH"])

# %%
# Import project-wide and PH2 specific variables and functions
import superheader as sup
from TRAIN.architecture.archeader import knn
# Out:
# Chosen class grouping: all-classes
#
#
# Directory /Users/diego/Desktop/iteso/TOG/ exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/data exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/src exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/bin exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/media exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/scores exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/data/PH1/all-classes exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/data/PH2/all-classes exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/data/PH3/all-classes exists. Continuing with execution
# device: mps
# Directory /Users/diego/Desktop/iteso/TOG/bin/load/TRAIN/distilbert-base-uncased exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/bin/load/TRAIN/prajjwal1/bert-tiny exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/bin/load/TRAIN/bert-base-uncased exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/bin/load/TRAIN/bert-large-uncased exists. Continuing with execution

# %%
TRAIN_classes = 'all-classes'

# %% [markdown]
# # Model training

# %% [markdown]
# ### Active Hand prediction

# %%
knn.find_best(sup.DATA_AH_PF, sup.active_hand_col, TRAIN_classes)
# Out:
# updating best... 0.9164369034994698
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf does not exist. Creating it and continuing with execution
# updating best... 0.9422057264050901
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9454931071049841
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9474549310710498
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9480381760339343
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.948356309650053
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 15}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.955355249204666
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9594909862142099
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9604984093319194
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9605514316012725
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 8}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9607635206786851
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9608165429480382
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 10}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9609225874867444
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 11}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9611876988335101
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 12}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9696712619300106
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9700424178154825
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 4}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9720572640509014
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9730116648992577
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9734358430540827
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9735418875927889
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 11}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9737539766702015
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 13}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9738069989395546
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 15}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9755037115588547
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 2}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9791622481442206
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.979745493107105
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 4}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9804347826086957
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9805938494167551
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 6}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9807529162248144
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9808589607635206
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 6}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9812831389183457
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9813361611876988
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 8}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9814422057264051
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 8, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9814952279957582
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 9, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9816542948038176
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 9, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9818663838812302
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 9, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9820254506892895
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 10, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9822905620360551
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 10, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9826086956521739
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 11, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 knn.find_best(sup.DATA_AH_PF, sup.active_hand_col, TRAIN_classes)
#
# File ~/Desktop/iteso/TOG/src/TRAIN/architecture/KNN/knn.py:130, in find_best(data_unit, label_col, class_list)
#     129 def find_best(data_unit, label_col, class_list):
# --> 130   try_data_configs(data_unit, label_col, class_list)
#     132   print_best(sup.TRAIN_KNN_CODE, data_unit)
#
# File ~/Desktop/iteso/TOG/src/TRAIN/architecture/KNN/knn.py:118, in try_data_configs(data_unit, label_col, class_list)
#     116   for kernel in sup.PH3_REDUCER_KERNEL_NAMES:
#     117     data_config["kernel"] = kernel
# --> 118     try_train_configs(data_config)
#     119 else:
#     120   data_config["kernel"] = ''
#
# File ~/Desktop/iteso/TOG/src/TRAIN/architecture/KNN/knn.py:89, in try_train_configs(data_config)
#      86   model = KNN(data_config=data_config, df=save_df, train_config=train_config)
#      88 model.fit()
# ---> 89 model.score()
#      91 keep_scores_knn(model)
#      92 update_best(model)
#
# File ~/Desktop/iteso/TOG/src/TRAIN/architecture/KNN/knn.py:45, in KNN.score(self)
#      44 def score(self):
# ---> 45   y_pred = self.predict(self.X_test)
#      47   self.accuracy = accuracy_score(self.y_test, y_pred)
#      48   return self.accuracy
#
# File ~/Desktop/iteso/TOG/src/TRAIN/architecture/KNN/knn.py:42, in KNN.predict(self, X)
#      41 def predict(self, X):
# ---> 42   return self.me.predict(X)
#
# File ~/miniconda3/envs/TOG_BERT_v2/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:274, in KNeighborsClassifier.predict(self, X)
#     271         return self.classes_[np.argmax(probabilities, axis=1)]
#     272     # In that case, we do not need the distances to perform
#     273     # the weighting so we do not compute them.
# --> 274     neigh_ind = self.kneighbors(X, return_distance=False)
#     275     neigh_dist = None
#     276 else:
#
# File ~/miniconda3/envs/TOG_BERT_v2/lib/python3.10/site-packages/sklearn/neighbors/_base.py:923, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     918     if issparse(X):
#     919         raise ValueError(
#     920             "%s does not work with sparse matrices. Densify the data, "
#     921             "or set algorithm='brute'" % self._fit_method
#     922         )
# --> 923     chunked_results = Parallel(n_jobs, prefer="threads")(
#     924         delayed(self._tree.query)(X[s], n_neighbors, return_distance)
#     925         for s in gen_even_slices(X.shape[0], n_jobs)
#     926     )
#     927 else:
#     928     raise ValueError("internal: _fit_method not recognized")
#
# File ~/miniconda3/envs/TOG_BERT_v2/lib/python3.10/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)
#      80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/miniconda3/envs/TOG_BERT_v2/lib/python3.10/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/miniconda3/envs/TOG_BERT_v2/lib/python3.10/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/miniconda3/envs/TOG_BERT_v2/lib/python3.10/site-packages/sklearn/utils/parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Sign prediction

# %%
knn.find_best(sup.DATA_S_PF, sup.class_numeric_column, TRAIN_classes)
# Out:
# updating best... 0.061581920903954805
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.06398305084745763
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.06765536723163842
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 8}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.06892655367231638
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 10}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.07062146892655367
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 12}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.07090395480225989
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 15}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.0711864406779661
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.07274011299435028
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 2}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.07796610169491526
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.08177966101694915
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.0847457627118644
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.08516949152542373
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 8}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.0884180790960452
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.08884180790960453
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 10}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.09152542372881356
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 11}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.13361581920903956
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.13827683615819208
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.1481638418079096
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 4}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.15028248587570622
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.15974576271186441
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 6}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.16327683615819208
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 8}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.1653954802259887
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.16751412429378532
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 11}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.16807909604519775
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 13}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.17274011299435027
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 14}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.17372881355932204
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 15}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.17669491525423728
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.18135593220338983
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.1943502824858757
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 4}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.20663841807909605
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.20889830508474577
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 6}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.21680790960451976
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.22062146892655368
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.22330508474576272
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 10}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.2274011299435028
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 11}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.23220338983050848
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 12}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.5
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.5125706214689265
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.5151129943502825
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 4}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.5199152542372881
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.5206214689265537
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 6}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.617090395480226
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.647316384180791
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 4, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.6509887005649717
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 5, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.6570621468926554
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 6, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.6615819209039548
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 6, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.696045197740113
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 7, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7059322033898305
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 8, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7110169491525423
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 9, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.719632768361582
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 10, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7512711864406779
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 11, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7535310734463276
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 12, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7649717514124293
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 13, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7661016949152543
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 14, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7706214689265537
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 15, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.840819209039548
# 	{'PH2': True, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.8436440677966102
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 8, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.8798022598870057
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 9, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.8867231638418079
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 10, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.890819209039548
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 11, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.9026836158192091
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 12, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.9077683615819209
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 13, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.9122881355932203
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 14, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.9141242937853107
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 15, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.9334745762711865
# 	{'PH2': False, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spf exists. Continuing with execution
# Data Unit: Spf
# Best score: 0.9334745762711865
# Best data config: {'PH2': False, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# Best train config: {'arch': 'KNN', 'k': 1}

# %%
knn.find_best(sup.DATA_S_PV, sup.class_numeric_column, TRAIN_classes)
# Out:
# updating best... 0.15932203389830507
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.16271186440677965
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 10}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.16779661016949152
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 13}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.18305084745762712
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 14}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.1864406779661017
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.3220338983050847
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.4186440677966102
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 3, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.47627118644067795
# 	{'PH2': True, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.523728813559322
# 	{'PH2': False, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.5254237288135594
# 	{'PH2': False, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 5, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.5389830508474577
# 	{'PH2': False, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 7, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.5406779661016949
# 	{'PH2': False, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 13, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.5508474576271186
# 	{'PH2': False, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 14, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.5627118644067797
# 	{'PH2': False, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 15, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.6067796610169491
# 	{'PH2': False, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/alpha-classes/KNN/Spv exists. Continuing with execution
# Data Unit: Spv
# Best score: 0.6067796610169491
# Best data config: {'PH2': False, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'alpha-classes'}
# Best train config: {'arch': 'KNN', 'k': 1}

# %% [markdown]
# # Score saving

# %%
import pandas as pd
from datetime import datetime

# %%
knn_scores_df = pd.DataFrame(sup.knn_score_tracker, columns=sup.knn_scores_columns)

# %%
knn_scores_df
# Out:
#          class_list  accuracy data_unit    PH2    PH3 reducer kernel  n   k
# 0     alpha-classes  0.915702      AHpf   True   True     pca   None  1   1
# 1     alpha-classes  0.907366      AHpf   True   True     pca   None  1   2
# 2     alpha-classes  0.938196      AHpf   True   True     pca   None  1   3
# 3     alpha-classes  0.934890      AHpf   True   True     pca   None  1   4
# 4     alpha-classes  0.941286      AHpf   True   True     pca   None  1   5
# ...             ...       ...       ...    ...    ...     ...    ... ..  ..
# 8185  alpha-classes  0.374576       Spv  False  False    None   None -1  11
# 8186  alpha-classes  0.359322       Spv  False  False    None   None -1  12
# 8187  alpha-classes  0.352542       Spv  False  False    None   None -1  13
# 8188  alpha-classes  0.340678       Spv  False  False    None   None -1  14
# 8189  alpha-classes  0.332203       Spv  False  False    None   None -1  15
#
# [8190 rows x 9 columns]

# %%
knn_scores_df.sort_values(by="accuracy", ascending=False).head(50)
# Out:
#          class_list  accuracy data_unit    PH2    PH3 reducer  kernel   n   k
# 1354  alpha-classes  0.984765      AHpf   True  False    None    None  -1   5
# 1324  alpha-classes  0.984765      AHpf   True   True    kpca  cosine  15   5
# 1264  alpha-classes  0.984693      AHpf   True   True     pca    None  15   5
# 1352  alpha-classes  0.984621      AHpf   True  False    None    None  -1   3
# 1084  alpha-classes  0.984621      AHpf   True   True     pca    None  13   5
# 1234  alpha-classes  0.984621      AHpf   True   True    kpca  cosine  14   5
# 964   alpha-classes  0.984549      AHpf   True   True    kpca  cosine  11   5
# 1355  alpha-classes  0.984549      AHpf   True  False    None    None  -1   6
# 1144  alpha-classes  0.984549      AHpf   True   True    kpca  cosine  13   5
# 1174  alpha-classes  0.984549      AHpf   True   True     pca    None  14   5
# 724   alpha-classes  0.984477      AHpf   True   True     pca    None   9   5
# 1054  alpha-classes  0.984477      AHpf   True   True    kpca  cosine  12   5
# 1353  alpha-classes  0.984477      AHpf   True  False    None    None  -1   4
# 996   alpha-classes  0.984477      AHpf   True   True     pca    None  12   7
# 1262  alpha-classes  0.984477      AHpf   True   True     pca    None  15   3
# 814   alpha-classes  0.984477      AHpf   True   True     pca    None  10   5
# 1086  alpha-classes  0.984405      AHpf   True   True     pca    None  13   7
# 1175  alpha-classes  0.984405      AHpf   True   True     pca    None  14   6
# 1266  alpha-classes  0.984405      AHpf   True   True     pca    None  15   7
# 1265  alpha-classes  0.984405      AHpf   True   True     pca    None  15   6
# 1263  alpha-classes  0.984333      AHpf   True   True     pca    None  15   4
# 1356  alpha-classes  0.984333      AHpf   True  False    None    None  -1   7
# 992   alpha-classes  0.984333      AHpf   True   True     pca    None  12   3
# 2718  alpha-classes  0.984333      AHpf  False  False    None    None  -1   4
# 994   alpha-classes  0.984333      AHpf   True   True     pca    None  12   5
# 1085  alpha-classes  0.984333      AHpf   True   True     pca    None  13   6
# 1323  alpha-classes  0.984333      AHpf   True   True    kpca  cosine  15   4
# 904   alpha-classes  0.984333      AHpf   True   True     pca    None  11   5
# 1176  alpha-classes  0.984333      AHpf   True   True     pca    None  14   7
# 1233  alpha-classes  0.984262      AHpf   True   True    kpca  cosine  14   4
# 1325  alpha-classes  0.984262      AHpf   True   True    kpca  cosine  15   6
# 997   alpha-classes  0.984262      AHpf   True   True     pca    None  12   8
# 1172  alpha-classes  0.984262      AHpf   True   True     pca    None  14   3
# 1326  alpha-classes  0.984190      AHpf   True   True    kpca  cosine  15   7
# 1173  alpha-classes  0.984190      AHpf   True   True     pca    None  14   4
# 1087  alpha-classes  0.984190      AHpf   True   True     pca    None  13   8
# 995   alpha-classes  0.984190      AHpf   True   True     pca    None  12   6
# 874   alpha-classes  0.984190      AHpf   True   True    kpca  cosine  10   5
# 909   alpha-classes  0.984190      AHpf   True   True     pca    None  11  10
# 784   alpha-classes  0.984190      AHpf   True   True    kpca  cosine   9   5
# 965   alpha-classes  0.984190      AHpf   True   True    kpca  cosine  11   6
# 1055  alpha-classes  0.984190      AHpf   True   True    kpca  cosine  12   6
# 1235  alpha-classes  0.984190      AHpf   True   True    kpca  cosine  14   6
# 905   alpha-classes  0.984190      AHpf   True   True     pca    None  11   6
# 2717  alpha-classes  0.984190      AHpf  False  False    None    None  -1   3
# 1082  alpha-classes  0.984190      AHpf   True   True     pca    None  13   3
# 785   alpha-classes  0.984118      AHpf   True   True    kpca  cosine   9   6
# 1177  alpha-classes  0.984118      AHpf   True   True     pca    None  14   8
# 1359  alpha-classes  0.984118      AHpf   True  False    None    None  -1  10
# 1357  alpha-classes  0.984118      AHpf   True  False    None    None  -1   8

# %%
now = datetime.now().strftime("%Y-%m-%d_%H:%M:%S")
sup.create_dir_if_not_exists(os.path.join(sup.TRAIN_SCORES_ROOT, TRAIN_classes, sup.TRAIN_KNN_CODE))
knn_scores_df.to_csv(os.path.join(sup.TRAIN_SCORES_ROOT, TRAIN_classes, sup.TRAIN_KNN_CODE, f"{now}.csv"), index=False)
# Out:
# Directory /Users/diego/Desktop/iteso/TOG/scores/alpha-classes/KNN exists. Continuing with execution
