sup.class_numeric_column, TRAIN_classes)
# Out:
# updating best... 0.6976744186046512 at 2025-06-13_16:21:00
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'two-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/two-classes/2/KNN/Spv does not exist. Creating it and continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/media/gen/TRAIN/two-classes/2/KNN/Spv/confusion exists. Continuing with execution
# updating best... 0.7441860465116279 at 2025-06-13_16:21:02
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'rbf', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'two-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/two-classes/2/KNN/Spv exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/media/gen/TRAIN/two-classes/2/KNN/Spv/confusion exists. Continuing with execution
# updating best... 0.7674418604651163 at 2025-06-13_16:21:02
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'rbf', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'two-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/two-classes/2/KNN/Spv exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/media/gen/TRAIN/two-classes/2/KNN/Spv/confusion exists. Continuing with execution
# updating best... 0.8372093023255814 at 2025-06-13_16:21:08
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'two-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/two-classes/2/KNN/Spv exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/media/gen/TRAIN/two-classes/2/KNN/Spv/confusion exists. Continuing with execution
# updating best... 0.8604651162790697 at 2025-06-13_16:21:08
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'two-classes'}
# 	{'arch': 'KNN', 'k': 2}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/two-classes/2/KNN/Spv exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/media/gen/TRAIN/two-classes/2/KNN/Spv/confusion exists. Continuing with execution
# updating best... 0.8837209302325582 at 2025-06-13_16:21:21
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 5, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'two-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/two-classes/2/KNN/Spv exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/media/gen/TRAIN/two-classes/2/KNN/Spv/confusion exists. Continuing with execution
# updating best... 0.9069767441860465 at 2025-06-13_16:21:26
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 6, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'two-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/two-classes/2/KNN/Spv exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/media/gen/TRAIN/two-classes/2/KNN/Spv/confusion exists. Continuing with execution
# updating best... 0.9302325581395349 at 2025-06-13_16:23:26
# 	{'PH2': False, 'PH3': False, 'reducer': '', 'kernel': '', 'n': 72, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'two-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/two-classes/2/KNN/Spv exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/media/gen/TRAIN/two-classes/2/KNN/Spv/confusion exists. Continuing with execution
# Data Unit: Spv
# Best score: 0.9302325581395349
# Best data config: {'PH2': False, 'PH3': False, 'reducer': '', 'kernel': '', 'n': 72, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'two-classes'}
# Best train config: {'arch': 'KNN', 'k': 1}

# %% [markdown]
# # Score saving

# %%
import pandas as pd
from datetime import datetime

# %%
knn_scores_df = pd.DataFrame(sup.knn_score_tracker, columns=sup.knn_scores_columns)

# %%
knn_scores_df
# Out:
#        class_list  accuracy data_unit    PH2    PH3 reducer kernel   n  k
# 0     two-classes  0.916168      AHpf   True   True     pca   None   1  1
# 1     two-classes  0.918164      AHpf   True   True     pca   None   1  2
# 2     two-classes  0.938124      AHpf   True   True     pca   None   1  3
# 3     two-classes  0.936128      AHpf   True   True     pca   None   1  4
# 4     two-classes  0.937126      AHpf   True   True     pca   None   1  5
# ...           ...       ...       ...    ...    ...     ...    ...  .. ..
# 3817  two-classes  0.883721       Spv  False  False    None   None  72  3
# 3818  two-classes  0.906977       Spv  False  False    None   None  72  4
# 3819  two-classes  0.860465       Spv  False  False    None   None  72  5
# 3820  two-classes  0.906977       Spv  False  False    None   None  72  6
# 3821  two-classes  0.906977       Spv  False  False    None   None  72  7
#
# [3822 rows x 9 columns]

# %%
knn_scores_df.sort_values(by="accuracy", ascending=False).head(50)
# Out:
#        class_list  accuracy data_unit    PH2    PH3 reducer  kernel   n  k
# 2331  two-classes  0.994141       Spf  False   True     pca    None  11  1
# 2289  two-classes  0.994141       Spf  False   True     pca    None  10  1
# 2499  two-classes  0.994141       Spf  False   True     pca    None  15  1
# 2373  two-classes  0.994141       Spf  False   True     pca    None  12  1
# 2205  two-classes  0.994141       Spf  False   True     pca    None   8  1
# 2415  two-classes  0.994141       Spf  False   True     pca    None  13  1
# 2247  two-classes  0.994141       Spf  False   True     pca    None   9  1
# 2457  two-classes  0.994141       Spf  False   True     pca    None  14  1
# 2290  two-classes  0.990234       Spf  False   True     pca    None  10  2
# 2207  two-classes  0.990234       Spf  False   True     pca    None   8  3
# 2527  two-classes  0.990234       Spf  False   True    kpca  cosine  15  1
# 2374  two-classes  0.990234       Spf  False   True     pca    None  12  2
# 2332  two-classes  0.990234       Spf  False   True     pca    None  11  2
# 2485  two-classes  0.990234       Spf  False   True    kpca  cosine  14  1
# 2324  two-classes  0.990234       Spf  False   True    umap    None  10  1
# 2451  two-classes  0.988281       Spf  False   True    umap    None  13  2
# 2534  two-classes  0.988281       Spf  False   True    umap    None  15  1
# 2325  two-classes  0.988281       Spf  False   True    umap    None  10  2
# 2443  two-classes  0.988281       Spf  False   True    kpca  cosine  13  1
# 2541  two-classes  0.988281       Spf  False  False    None    None  72  1
# 2375  two-classes  0.988281       Spf  False   True     pca    None  12  3
# 2416  two-classes  0.988281       Spf  False   True     pca    None  13  2
# 2450  two-classes  0.988281       Spf  False   True    umap    None  13  1
# 2249  two-classes  0.988281       Spf  False   True     pca    None   9  3
# 2501  two-classes  0.986328       Spf  False   True     pca    None  15  3
# 2326  two-classes  0.986328       Spf  False   True    umap    None  10  3
# 2500  two-classes  0.986328       Spf  False   True     pca    None  15  2
# 2291  two-classes  0.986328       Spf  False   True     pca    None  10  3
# 2072  two-classes  0.986328       Spf  False   True    umap    None   4  1
# 2377  two-classes  0.986328       Spf  False   True     pca    None  12  5
# 2419  two-classes  0.986328       Spf  False   True     pca    None  13  5
# 2417  two-classes  0.986328       Spf  False   True     pca    None  13  3
# 2282  two-classes  0.986328       Spf  False   True    umap    None   9  1
# 2401  two-classes  0.986328       Spf  False   True    kpca  cosine  12  1
# 2333  two-classes  0.986328       Spf  False   True     pca    None  11  3
# 2409  two-classes  0.986328       Spf  False   True    umap    None  12  2
# 2335  two-classes  0.986328       Spf  False   True     pca    None  11  5
# 550   two-classes  0.986028      AHpf   True   True     pca    None  14  5
# 339   two-classes  0.986028      AHpf   True   True     pca    None   9  4
# 326   two-classes  0.986028      AHpf   True   True    kpca  cosine   8  5
# 507   two-classes  0.986028      AHpf   True   True     pca    None  13  4
# 549   two-classes  0.986028      AHpf   True   True     pca    None  14  4
# 297   two-classes  0.986028      AHpf   True   True     pca    None   8  4
# 634   two-classes  0.986028      AHpf   True  False    None    None  75  5
# 381   two-classes  0.986028      AHpf   True   True     pca    None  10  4
# 592   two-classes  0.986028      AHpf   True   True     pca    None  15  5
# 591   two-classes  0.986028      AHpf   True   True     pca    None  15  4
# 465   two-classes  0.986028      AHpf   True   True     pca    None  12  4
# 473   two-classes  0.986028      AHpf   True   True    kpca    poly  12  5
# 214   two-classes  0.985030      AHpf   True   True     pca    None   6  5

# %%
now = datetime.now().strftime("%Y-%m-%d_%H:%M:%S")
sup.create_dir_if_not_exists(os.path.join(sup.TRAIN_SCORES_ROOT, TRAIN_classes, sup.TRAIN_KNN_CODE))
knn_scores_df.to_csv(os.path.join(sup.TRAIN_SCORES_ROOT, TRAIN_classes, sup.TRAIN_KNN_CODE, f"{now}.csv"), index=False)
# Out:
# Directory /Users/diego/Desktop/iteso/TOG/scores/two-classes/KNN exists. Continuing with execution
