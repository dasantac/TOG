# %% [markdown]
# # Context
# This notebook drives the training process for different models.

# %%
# Set project's environment variables
import os
import sys
from dotenv import load_dotenv
load_dotenv(dotenv_path="../../../project.env")
sys.path.append(os.environ["PYTHONPATH"])

# %%
# Import project-wide and PH2 specific variables and functions
import superheader as sup
from TRAIN.architecture.archeader import knn
# Out:
# Chosen class grouping: all-classes
#
#
# Directory /Users/diego/Desktop/iteso/TOG/ exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/data exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/src exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/bin exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/media exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/scores exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/data/PH1/all-classes exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/data/PH2/all-classes exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/data/PH3/all-classes exists. Continuing with execution
# device: mps
# Directory /Users/diego/Desktop/iteso/TOG/bin/load/TRAIN/distilbert-base-uncased exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/bin/load/TRAIN/prajjwal1/bert-tiny exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/bin/load/TRAIN/bert-base-uncased exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/bin/load/TRAIN/bert-large-uncased exists. Continuing with execution

# %%
TRAIN_classes = 'all-classes'

# %% [markdown]
# # Model training

# %% [markdown]
# ### Active Hand prediction

# %%
knn.find_best(sup.DATA_AH_PF, sup.active_hand_col, TRAIN_classes)
# Out:
# updating best... 0.9164369034994698
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf does not exist. Creating it and continuing with execution
# updating best... 0.9422057264050901
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9454931071049841
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9474549310710498
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9480381760339343
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.948356309650053
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 15}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.955355249204666
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9594909862142099
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9604984093319194
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9605514316012725
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 8}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9607635206786851
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9608165429480382
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 10}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9609225874867444
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 11}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9611876988335101
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 12}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9696712619300106
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9700424178154825
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 4}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9720572640509014
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9730116648992577
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9734358430540827
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9735418875927889
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 11}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9737539766702015
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 13}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9738069989395546
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 15}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9755037115588547
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 2}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9791622481442206
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.979745493107105
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 4}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9804347826086957
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9805938494167551
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 6}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9807529162248144
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9808589607635206
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 6}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9812831389183457
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9813361611876988
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 8}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9814422057264051
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 8, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9814952279957582
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 9, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9816542948038176
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 9, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9818663838812302
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 9, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9820254506892895
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 10, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9822905620360551
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 10, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9826086956521739
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'cosine', 'n': 11, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9828207847295864
# 	{'PH2': True, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# updating best... 0.9829268292682927
# 	{'PH2': True, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/AHpf exists. Continuing with execution
# Data Unit: AHpf
# Best score: 0.9829268292682927
# Best data config: {'PH2': True, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'AHpf', 'label_col': 'active_hand', 'class_list': 'all-classes'}
# Best train config: {'arch': 'KNN', 'k': 7}

# %% [markdown]
# ### Sign prediction

# %%
knn.find_best(sup.DATA_S_PF, sup.class_numeric_column, TRAIN_classes)
# Out:
# updating best... 0.05248389108293494
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf does not exist. Creating it and continuing with execution
# updating best... 0.05393889004364997
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.057160673456661815
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 11}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.05726460195385575
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 13}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.05736853045104968
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 14}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.05986281438370401
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 15}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.06412388276865516
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.0655788817293702
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 8}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.0666181667013095
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.1115152774890875
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.11193099147786323
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.11723134483475368
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 4}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.12138848472251092
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.12398669715235917
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 6}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.13136562045312825
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.13344419039700686
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 8}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.13625025982124297
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.13749740178757014
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 10}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.14082311369777592
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 11}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.14123882768655166
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 12}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.1417584701725213
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 13}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.1447723965911453
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 15}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.1539181043442112
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.1573477447516109
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.17179380586156723
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 4}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.17886094367075453
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.18655165246310537
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 6}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.19185200581999584
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.19767200166285595
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 8}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.2059862814383704
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.20900020785699439
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 10}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.20931199334857617
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 11}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.21263770525878195
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 12}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.21502806069424235
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 13}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.21565163167740595
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 15}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.48825607981708585
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.49542714612346705
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.5086260652670962
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 4}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.5112242776969445
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.5893785075867803
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.5901060070671378
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 3}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.5935356474745375
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 4}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.6159842028684265
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 4, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.628663479526086
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 5, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.6364581168156308
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 6, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.6686759509457493
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 7, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.6807316566202453
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 8, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.691644148825608
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 9, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7001662855955103
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 10, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.729162336312617
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 11, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7337351901891499
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 12, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7449594678860944
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 13, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7478694658075244
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 14, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.7528580336728331
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 15, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.8316358345458325
# 	{'PH2': True, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.8320515485346082
# 	{'PH2': False, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 7, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.8476408231136978
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 8, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.878715443774683
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 9, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.8890043649968822
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 10, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.8921222199127
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 11, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.902722926626481
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 12, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.9076075659945957
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 13, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.9123882768655165
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 14, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.9164414882560799
# 	{'PH2': False, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 15, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# updating best... 0.9418000415713988
# 	{'PH2': False, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spf exists. Continuing with execution
# Data Unit: Spf
# Best score: 0.9418000415713988
# Best data config: {'PH2': False, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spf', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# Best train config: {'arch': 'KNN', 'k': 1}

# %%
knn.find_best(sup.DATA_S_PV, sup.class_numeric_column, TRAIN_classes)
# Out:
# updating best... 0.11471321695760599
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv does not exist. Creating it and continuing with execution
# updating best... 0.12094763092269327
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 5}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.12219451371571072
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 7}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.1259351620947631
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 8}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.12718204488778054
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 9}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.13092269326683292
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 10}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.13216957605985039
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 11}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.13591022443890274
# 	{'PH2': True, 'PH3': True, 'reducer': 'kpca', 'kernel': 'poly', 'n': 1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.2630922693266833
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 2, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.2743142144638404
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.3640897755610973
# 	{'PH2': True, 'PH3': True, 'reducer': 'pca', 'kernel': '', 'n': 3, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.371571072319202
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 7, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.37531172069825436
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 10, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.3765586034912718
# 	{'PH2': True, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 12, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.415211970074813
# 	{'PH2': True, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.4476309226932668
# 	{'PH2': False, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 2, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.516209476309227
# 	{'PH2': False, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 3, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.5224438902743143
# 	{'PH2': False, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 5, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.527431421446384
# 	{'PH2': False, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 6, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.5324189526184538
# 	{'PH2': False, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 8, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.5411471321695761
# 	{'PH2': False, 'PH3': True, 'reducer': 'umap', 'kernel': '', 'n': 11, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# updating best... 0.5698254364089775
# 	{'PH2': False, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# 	{'arch': 'KNN', 'k': 1}
# Directory /Users/diego/Desktop/iteso/TOG/bin/gen/TRAIN/all-classes/KNN/Spv exists. Continuing with execution
# Data Unit: Spv
# Best score: 0.5698254364089775
# Best data config: {'PH2': False, 'PH3': False, 'reducer': '', 'kernel': '', 'n': -1, 'data_unit': 'Spv', 'label_col': 'class_numeric', 'class_list': 'all-classes'}
# Best train config: {'arch': 'KNN', 'k': 1}

# %% [markdown]
# # Score saving

# %%
import pandas as pd
from datetime import datetime

# %%
knn_scores_df = pd.DataFrame(sup.knn_score_tracker, columns=sup.knn_scores_columns)

# %%
knn_scores_df
# Out:
#        class_list  accuracy data_unit    PH2    PH3 reducer kernel  n   k
# 0     all-classes  0.916437      AHpf   True   True     pca   None  1   1
# 1     all-classes  0.914104      AHpf   True   True     pca   None  1   2
# 2     all-classes  0.942206      AHpf   True   True     pca   None  1   3
# 3     all-classes  0.940244      AHpf   True   True     pca   None  1   4
# 4     all-classes  0.945493      AHpf   True   True     pca   None  1   5
# ...           ...       ...       ...    ...    ...     ...    ... ..  ..
# 8185  all-classes  0.322943       Spv  False  False    None   None -1  11
# 8186  all-classes  0.311721       Spv  False  False    None   None -1  12
# 8187  all-classes  0.314214       Spv  False  False    None   None -1  13
# 8188  all-classes  0.304239       Spv  False  False    None   None -1  14
# 8189  all-classes  0.290524       Spv  False  False    None   None -1  15
#
# [8190 rows x 9 columns]

# %%
knn_scores_df.sort_values(by="accuracy", ascending=False).head(50)
# Out:
#        class_list  accuracy data_unit    PH2    PH3 reducer  kernel   n   k
# 1356  all-classes  0.982927      AHpf   True  False    None    None  -1   7
# 1354  all-classes  0.982821      AHpf   True  False    None    None  -1   5
# 966   all-classes  0.982609      AHpf   True   True    kpca  cosine  11   7
# 1326  all-classes  0.982609      AHpf   True   True    kpca  cosine  15   7
# 1236  all-classes  0.982609      AHpf   True   True    kpca  cosine  14   7
# 1056  all-classes  0.982609      AHpf   True   True    kpca  cosine  12   7
# 1146  all-classes  0.982503      AHpf   True   True    kpca  cosine  13   7
# 1355  all-classes  0.982450      AHpf   True  False    None    None  -1   6
# 1353  all-classes  0.982344      AHpf   True  False    None    None  -1   4
# 876   all-classes  0.982291      AHpf   True   True    kpca  cosine  10   7
# 1324  all-classes  0.982291      AHpf   True   True    kpca  cosine  15   5
# 1234  all-classes  0.982238      AHpf   True   True    kpca  cosine  14   5
# 1328  all-classes  0.982238      AHpf   True   True    kpca  cosine  15   9
# 1357  all-classes  0.982238      AHpf   True  False    None    None  -1   8
# 964   all-classes  0.982238      AHpf   True   True    kpca  cosine  11   5
# 1057  all-classes  0.982238      AHpf   True   True    kpca  cosine  12   8
# 1058  all-classes  0.982238      AHpf   True   True    kpca  cosine  12   9
# 1174  all-classes  0.982185      AHpf   True   True     pca    None  14   5
# 1086  all-classes  0.982185      AHpf   True   True     pca    None  13   7
# 1238  all-classes  0.982185      AHpf   True   True    kpca  cosine  14   9
# 1176  all-classes  0.982185      AHpf   True   True     pca    None  14   7
# 1148  all-classes  0.982185      AHpf   True   True    kpca  cosine  13   9
# 1054  all-classes  0.982185      AHpf   True   True    kpca  cosine  12   5
# 996   all-classes  0.982185      AHpf   True   True     pca    None  12   7
# 1327  all-classes  0.982185      AHpf   True   True    kpca  cosine  15   8
# 1145  all-classes  0.982185      AHpf   True   True    kpca  cosine  13   6
# 1323  all-classes  0.982185      AHpf   True   True    kpca  cosine  15   4
# 1055  all-classes  0.982185      AHpf   True   True    kpca  cosine  12   6
# 968   all-classes  0.982131      AHpf   True   True    kpca  cosine  11   9
# 1264  all-classes  0.982131      AHpf   True   True     pca    None  15   5
# 1266  all-classes  0.982131      AHpf   True   True     pca    None  15   7
# 2719  all-classes  0.982131      AHpf  False  False    None    None  -1   5
# 1084  all-classes  0.982131      AHpf   True   True     pca    None  13   5
# 965   all-classes  0.982131      AHpf   True   True    kpca  cosine  11   6
# 1233  all-classes  0.982131      AHpf   True   True    kpca  cosine  14   4
# 1358  all-classes  0.982131      AHpf   True  False    None    None  -1   9
# 1144  all-classes  0.982078      AHpf   True   True    kpca  cosine  13   5
# 967   all-classes  0.982078      AHpf   True   True    kpca  cosine  11   8
# 1235  all-classes  0.982078      AHpf   True   True    kpca  cosine  14   6
# 906   all-classes  0.982078      AHpf   True   True     pca    None  11   7
# 1147  all-classes  0.982078      AHpf   True   True    kpca  cosine  13   8
# 1143  all-classes  0.982025      AHpf   True   True    kpca  cosine  13   4
# 874   all-classes  0.982025      AHpf   True   True    kpca  cosine  10   5
# 1237  all-classes  0.982025      AHpf   True   True    kpca  cosine  14   8
# 1085  all-classes  0.982025      AHpf   True   True     pca    None  13   6
# 1325  all-classes  0.981972      AHpf   True   True    kpca  cosine  15   6
# 1088  all-classes  0.981972      AHpf   True   True     pca    None  13   9
# 1175  all-classes  0.981972      AHpf   True   True     pca    None  14   6
# 995   all-classes  0.981919      AHpf   True   True     pca    None  12   6
# 969   all-classes  0.981919      AHpf   True   True    kpca  cosine  11  10

# %%
now = datetime.now().strftime("%Y-%m-%d_%H:%M:%S")
sup.create_dir_if_not_exists(os.path.join(sup.TRAIN_SCORES_ROOT, TRAIN_classes, sup.TRAIN_KNN_CODE))
knn_scores_df.to_csv(os.path.join(sup.TRAIN_SCORES_ROOT, TRAIN_classes, sup.TRAIN_KNN_CODE, f"{now}.csv"), index=False)
# Out:
# Directory /Users/diego/Desktop/iteso/TOG/scores/all-classes/KNN does not exist. Creating it and continuing with execution
