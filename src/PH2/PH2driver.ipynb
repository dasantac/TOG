# %% [markdown]
# # Context
# Phase two of this project is feature transformation.\
# This notebook drives this process.

# %%
# Set project's environment variables
import os
import sys
from dotenv import load_dotenv
load_dotenv(dotenv_path="../project.env")
sys.path.append(os.environ["PYTHONPATH"])

# %%
# Import project-wide and PH2 specific variables and functions
import superheader as sup
import PH2header as ph2
# Out:
# Chosen class grouping: two-classes
#
#
# Directory /Users/diego/Desktop/iteso/TOG/ exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/data exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/src exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/bin exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/media exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/scores exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/data/PH1/two-classes exists. Continuing with execution
# Directory /Users/diego/Desktop/iteso/TOG/data/PH2/two-classes exists. Continuing with execution

# %% [markdown]
# # Source dataframe loading

# %%
import pandas as pd

# %% [markdown]
# ## Active hand detection

# %%
PH1_ah_frame_df = pd.read_csv(sup.PH1_DATA_AH_PF_CSV)
PH1_ah_frame_df
# Out:
#                                                  fileid person_id  cycle_num  \
# 0         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 1         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 2         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 3         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 4         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# ...                                                 ...       ...        ...
# 5001  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5002  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5003  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5004  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5005  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
#
#       handedness class_name  class_numeric  current_frame       h0x       h0y  \
# 0              0          a              0              0  0.356595  0.485021
# 1              0          a              0              0  0.567594  0.906298
# 2              0          a              0              1  0.352816  0.484037
# 3              0          a              0              1  0.567833  0.905873
# 4              0          a              0              2  0.351332  0.480660
# ...          ...        ...            ...            ...       ...       ...
# 5001           1          b              1              9  0.405674  0.764709
# 5002           1          b              1             10  0.633578  0.386601
# 5003           1          b              1             10  0.404680  0.765115
# 5004           1          b              1             11  0.633556  0.386977
# 5005           1          b              1             11  0.404066  0.765756
#
#                h0z  ...       p0x       p0y       p0z      p11x      p11y  \
# 0    -1.312914e-07  ...  0.509847  0.324974 -0.511315  0.582418  0.521928
# 1     4.943682e-09  ...  0.509847  0.324974 -0.511315  0.582418  0.521928
# 2    -1.180915e-07  ...  0.513431  0.326082 -0.519151  0.579848  0.519345
# 3     4.337321e-09  ...  0.513431  0.326082 -0.519151  0.579848  0.519345
# 4    -1.254345e-07  ...  0.511904  0.326614 -0.538389  0.582581  0.522652
# ...            ...  ...       ...       ...       ...       ...       ...
# 5001  5.895547e-08  ...  0.485571  0.225081 -0.449431  0.574521  0.399775
# 5002 -1.037258e-07  ...  0.484376  0.228379 -0.438624  0.573325  0.403236
# 5003  4.365882e-08  ...  0.484376  0.228379 -0.438624  0.573325  0.403236
# 5004 -1.034930e-07  ...  0.482275  0.226709 -0.417354  0.574424  0.403286
# 5005  5.479360e-08  ...  0.482275  0.226709 -0.417354  0.574424  0.403286
#
#           p11z      p12x      p12y      p12z  active_hand
# 0    -0.164979  0.419079  0.505322 -0.183779            1
# 1    -0.164979  0.419079  0.505322 -0.183779            0
# 2    -0.151877  0.419200  0.498523 -0.208451            1
# 3    -0.151877  0.419200  0.498523 -0.208451            0
# 4    -0.176160  0.420109  0.498809 -0.215022            1
# ...        ...       ...       ...       ...          ...
# 5001 -0.116570  0.403689  0.412528 -0.128586            0
# 5002 -0.096671  0.400964  0.415107 -0.109301            1
# 5003 -0.096671  0.400964  0.415107 -0.109301            0
# 5004 -0.096126  0.401220  0.413737 -0.091982            1
# 5005 -0.096126  0.401220  0.413737 -0.091982            0
#
# [5006 rows x 80 columns]

# %% [markdown]
# # Feature transformations

# %% [markdown]
# ## Active hand detection

# %% [markdown]
# #### Hand transformations

# %% [markdown]
# ##### Center of Gravity

# %%
PH2_AH_FRM_h_cog_df = PH1_ah_frame_df.copy()

PH2_AH_FRM_h_cog_df[sup.pf_mean_hand_columns] = PH2_AH_FRM_h_cog_df[sup.pf_hand_landmark_columns].apply(ph2.hand.CenterOfGravity, axis=1)
PH2_AH_FRM_h_cog_df
# Out:
#                                                  fileid person_id  cycle_num  \
# 0         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 1         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 2         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 3         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 4         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# ...                                                 ...       ...        ...
# 5001  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5002  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5003  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5004  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5005  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
#
#       handedness class_name  class_numeric  current_frame       h0x       h0y  \
# 0              0          a              0              0  0.356595  0.485021
# 1              0          a              0              0  0.567594  0.906298
# 2              0          a              0              1  0.352816  0.484037
# 3              0          a              0              1  0.567833  0.905873
# 4              0          a              0              2  0.351332  0.480660
# ...          ...        ...            ...            ...       ...       ...
# 5001           1          b              1              9  0.405674  0.764709
# 5002           1          b              1             10  0.633578  0.386601
# 5003           1          b              1             10  0.404680  0.765115
# 5004           1          b              1             11  0.633556  0.386977
# 5005           1          b              1             11  0.404066  0.765756
#
#                h0z  ...      p11x      p11y      p11z      p12x      p12y  \
# 0    -1.312914e-07  ...  0.582418  0.521928 -0.164979  0.419079  0.505322
# 1     4.943682e-09  ...  0.582418  0.521928 -0.164979  0.419079  0.505322
# 2    -1.180915e-07  ...  0.579848  0.519345 -0.151877  0.419200  0.498523
# 3     4.337321e-09  ...  0.579848  0.519345 -0.151877  0.419200  0.498523
# 4    -1.254345e-07  ...  0.582581  0.522652 -0.176160  0.420109  0.498809
# ...            ...  ...       ...       ...       ...       ...       ...
# 5001  5.895547e-08  ...  0.574521  0.399775 -0.116570  0.403689  0.412528
# 5002 -1.037258e-07  ...  0.573325  0.403236 -0.096671  0.400964  0.415107
# 5003  4.365882e-08  ...  0.573325  0.403236 -0.096671  0.400964  0.415107
# 5004 -1.034930e-07  ...  0.574424  0.403286 -0.096126  0.401220  0.413737
# 5005  5.479360e-08  ...  0.574424  0.403286 -0.096126  0.401220  0.413737
#
#           p12z  active_hand  h_mean_x  h_mean_y  h_mean_z
# 0    -0.183779            1  0.360239  0.416955 -0.006689
# 1    -0.183779            0  0.561710  0.987890 -0.009604
# 2    -0.208451            1  0.358858  0.415220 -0.005975
# 3    -0.208451            0  0.561693  0.987804 -0.009676
# 4    -0.215022            1  0.357507  0.414159 -0.006603
# ...        ...          ...       ...       ...       ...
# 5001 -0.128586            0  0.427331  0.818829 -0.031451
# 5002 -0.109301            1  0.631197  0.275317 -0.009246
# 5003 -0.109301            0  0.426652  0.818555 -0.029639
# 5004 -0.091982            1  0.631751  0.276256 -0.009032
# 5005 -0.091982            0  0.426416  0.818708 -0.031074
#
# [5006 rows x 83 columns]

# %% [markdown]
# ##### Normal Vector

# %%
PH2_AH_FRM_h_v123_df = PH2_AH_FRM_h_cog_df.copy()

PH2_AH_FRM_h_v123_df[sup.pf_h_v123_columns] = PH2_AH_FRM_h_v123_df[[sup.handedness_column]+sup.pf_hand_landmark_columns].apply(ph2.hand.NormalVector, axis=1)
PH2_AH_FRM_h_v123_df
# Out:
#                                                  fileid person_id  cycle_num  \
# 0         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 1         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 2         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 3         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 4         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# ...                                                 ...       ...        ...
# 5001  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5002  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5003  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5004  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5005  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
#
#       handedness class_name  class_numeric  current_frame       h0x       h0y  \
# 0              0          a              0              0  0.356595  0.485021
# 1              0          a              0              0  0.567594  0.906298
# 2              0          a              0              1  0.352816  0.484037
# 3              0          a              0              1  0.567833  0.905873
# 4              0          a              0              2  0.351332  0.480660
# ...          ...        ...            ...            ...       ...       ...
# 5001           1          b              1              9  0.405674  0.764709
# 5002           1          b              1             10  0.633578  0.386601
# 5003           1          b              1             10  0.404680  0.765115
# 5004           1          b              1             11  0.633556  0.386977
# 5005           1          b              1             11  0.404066  0.765756
#
#                h0z  ...  h_mean_z     h_v1x     h_v1y     h_v1z     h_v2x  \
# 0    -1.312914e-07  ... -0.006689  0.057899 -0.998047 -0.023436 -0.221157
# 1     4.943682e-09  ... -0.009604 -0.193123  0.967382 -0.163938  0.143440
# 2    -1.180915e-07  ... -0.005975  0.101697 -0.994756 -0.010856 -0.171527
# 3     4.337321e-09  ... -0.009676 -0.197447  0.966163 -0.165960  0.134540
# 4    -1.254345e-07  ... -0.006603  0.107233 -0.993941 -0.024124 -0.178196
# ...            ...  ...       ...       ...       ...       ...       ...
# 5001  5.895547e-08  ... -0.031451  0.436674  0.291370 -0.851128 -0.140729
# 5002 -1.037258e-07  ... -0.009246 -0.055901 -0.998172 -0.022960  0.168659
# 5003  4.365882e-08  ... -0.029639  0.460711  0.295946 -0.836756 -0.139121
# 5004 -1.034930e-07  ... -0.009032 -0.054590 -0.998255 -0.022497  0.172534
# 5005  5.479360e-08  ... -0.031074  0.439414  0.279914 -0.853559 -0.128566
#
#          h_v2y     h_v2z     h_v3x     h_v3y     h_v3z
# 0    -0.971920 -0.080376  0.057440  0.009837 -0.276999
# 1     0.980908 -0.131321  0.033770 -0.048876 -0.328197
# 2    -0.982976 -0.065856  0.054840  0.008559 -0.270593
# 3     0.981961 -0.132856  0.034606 -0.048560 -0.323873
# 4    -0.980435 -0.083623  0.059464  0.013266 -0.282252
# ...        ...       ...       ...       ...       ...
# 5001  0.687971 -0.711963 -0.378107 -0.430674 -0.341423
# 5002 -0.984704 -0.043723 -0.021034  0.006317 -0.223397
# 5003  0.709019 -0.691331 -0.388680 -0.434914 -0.367825
# 5004 -0.984122 -0.041657 -0.019445  0.006155 -0.225956
# 5005  0.688370 -0.713876 -0.387741 -0.423425 -0.338467
#
# [5006 rows x 92 columns]

# %% [markdown]
# ##### Change of Base

# %%
PH2_AH_FRM_h_wrist_df = PH2_AH_FRM_h_v123_df.copy()

PH2_AH_FRM_h_wrist_df[sup.pf_wrist_hand_landmark_columns] = PH2_AH_FRM_h_wrist_df[sup.pf_hand_landmark_columns+sup.pf_h_v123_columns].apply(ph2.hand.ChangeOfBase, axis=1)
PH2_AH_FRM_h_wrist_df
# Out:
#                                                  fileid person_id  cycle_num  \
# 0         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 1         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 2         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 3         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 4         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# ...                                                 ...       ...        ...
# 5001  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5002  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5003  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5004  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5005  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
#
#       handedness class_name  class_numeric  current_frame       h0x       h0y  \
# 0              0          a              0              0  0.356595  0.485021
# 1              0          a              0              0  0.567594  0.906298
# 2              0          a              0              1  0.352816  0.484037
# 3              0          a              0              1  0.567833  0.905873
# 4              0          a              0              2  0.351332  0.480660
# ...          ...        ...            ...            ...       ...       ...
# 5001           1          b              1              9  0.405674  0.764709
# 5002           1          b              1             10  0.633578  0.386601
# 5003           1          b              1             10  0.404680  0.765115
# 5004           1          b              1             11  0.633556  0.386977
# 5005           1          b              1             11  0.404066  0.765756
#
#                h0z  ...     wh17z     wh18x     wh18y     wh18z     wh19x  \
# 0    -1.312914e-07  ...  1.386633 -1.901797 -0.125334  1.370475 -1.845207
# 1     4.943682e-09  ...  2.916156  2.679427  1.048473  2.925472  2.483835
# 2    -1.180915e-07  ...  1.427593 -1.916373 -0.196840  1.411701 -1.857026
# 3     4.337321e-09  ...  2.959678  2.702151  1.079497  2.968985  2.503209
# 4    -1.254345e-07  ...  1.341163 -1.840481 -0.215973  1.324809 -1.783978
# ...            ...  ...       ...       ...       ...       ...       ...
# 5001  5.895547e-08  ...  0.471852 -0.209436  1.648398  0.457947 -0.154789
# 5002 -1.037258e-07  ...  1.667411  1.068108 -0.115331  1.682057  1.452763
# 5003  4.365882e-08  ...  0.471814 -0.188836  1.589570  0.458964 -0.139648
# 5004 -1.034930e-07  ...  1.658150  1.043974 -0.112296  1.671366  1.428038
# 5005  5.479360e-08  ...  0.468082 -0.170935  1.656151  0.455658 -0.119290
#
#          wh19y     wh19z     wh20x     wh20y     wh20z
# 0    -0.126410  1.388787 -1.793037 -0.122584  1.415105
# 1     1.005685  2.889273  2.556190  1.023228  2.897902
# 2    -0.194359  1.428379 -1.808238 -0.188388  1.455144
# 3     1.034866  2.932061  2.575259  1.052822  2.940708
# 4    -0.213796  1.341799 -1.733032 -0.207673  1.368740
# ...        ...       ...       ...       ...       ...
# 5001  1.620231  0.467813 -0.191437  1.667917  0.463001
# 5002 -0.132146  1.611849  1.325932 -0.123035  1.644227
# 5003  1.562799  0.468390 -0.175106  1.610118  0.463674
# 5004 -0.128974  1.606707  1.305477 -0.120258  1.637927
# 5005  1.626340  0.464174 -0.154720  1.674291  0.458947
#
# [5006 rows x 155 columns]

# %% [markdown]
# #### Pose transformations

# %% [markdown]
# ##### Normal Vector

# %%
PH2_AH_FRM_p_v123_df = PH2_AH_FRM_h_wrist_df.copy()

PH2_AH_FRM_p_v123_df[sup.pf_p_v123_columns] = PH2_AH_FRM_p_v123_df[sup.pf_pose_landmark_columns].apply(ph2.pose.NormalVector, axis=1)
PH2_AH_FRM_p_v123_df
# Out:
#                                                  fileid person_id  cycle_num  \
# 0         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 1         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 2         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 3         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 4         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# ...                                                 ...       ...        ...
# 5001  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5002  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5003  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5004  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5005  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
#
#       handedness class_name  class_numeric  current_frame       h0x       h0y  \
# 0              0          a              0              0  0.356595  0.485021
# 1              0          a              0              0  0.567594  0.906298
# 2              0          a              0              1  0.352816  0.484037
# 3              0          a              0              1  0.567833  0.905873
# 4              0          a              0              2  0.351332  0.480660
# ...          ...        ...            ...            ...       ...       ...
# 5001           1          b              1              9  0.405674  0.764709
# 5002           1          b              1             10  0.633578  0.386601
# 5003           1          b              1             10  0.404680  0.765115
# 5004           1          b              1             11  0.633556  0.386977
# 5005           1          b              1             11  0.404066  0.765756
#
#                h0z  ...     wh20z     p_v1x     p_v1y     p_v1z     p_v2x  \
# 0    -1.312914e-07  ...  1.415105  0.179198  0.486335  0.855200 -0.235907
# 1     4.943682e-09  ...  2.897902  0.179198  0.486335  0.855200 -0.235907
# 2    -1.180915e-07  ...  1.455144  0.158022  0.459822  0.873838 -0.256321
# 3     4.337321e-09  ...  2.940708  0.158022  0.459822  0.873838 -0.256321
# 4    -1.254345e-07  ...  1.368740  0.169127  0.469108  0.866795 -0.243047
# ...            ...  ...       ...       ...       ...       ...       ...
# 5001  5.895547e-08  ...  0.463001  0.230263  0.452225  0.861668 -0.215194
# 5002 -1.037258e-07  ...  1.644227  0.225627  0.443540  0.867390 -0.215170
# 5003  4.365882e-08  ...  0.463674  0.225627  0.443540  0.867390 -0.215170
# 5004 -1.034930e-07  ...  1.637927  0.243802  0.467179  0.849885 -0.211109
# 5005  5.479360e-08  ...  0.458947  0.243802  0.467179  0.849885 -0.211109
#
#          p_v2y     p_v2z     p_v3x     p_v3y     p_v3z
# 0     0.468723  0.851262  0.013147 -0.354292  0.198724
# 1     0.468723  0.851262  0.013147 -0.354292  0.198724
# 2     0.469066  0.845149 -0.021270 -0.357535  0.191985
# 3     0.469066  0.845149 -0.021270 -0.357535  0.191985
# 4     0.455927  0.856189  0.006450 -0.355477  0.191125
# ...        ...       ...       ...       ...       ...
# 5001  0.492630  0.843212 -0.043162 -0.379586  0.210751
# 5002  0.481684  0.849519 -0.041012 -0.378310  0.204117
# 5003  0.481684  0.849519 -0.041012 -0.378310  0.204117
# 5004  0.487119  0.847436 -0.018091 -0.386025  0.217386
# 5005  0.487119  0.847436 -0.018091 -0.386025  0.217386
#
# [5006 rows x 164 columns]

# %% [markdown]
# ##### Change of Base

# %%
PH2_AH_FRM_p_chest_df = PH2_AH_FRM_p_v123_df.copy()

PH2_AH_FRM_p_chest_df[sup.pf_chest_pose_landmark_columns] = PH2_AH_FRM_p_chest_df[sup.pf_pose_landmark_columns+sup.pf_p_v123_columns+sup.pf_mean_hand_columns].apply(ph2.pose.ChangeOfBase, axis=1)
PH2_AH_FRM_p_chest_df
# Out:
#                                                  fileid person_id  cycle_num  \
# 0         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 1         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 2         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 3         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 4         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# ...                                                 ...       ...        ...
# 5001  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5002  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5003  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5004  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5005  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
#
#       handedness class_name  class_numeric  current_frame       h0x       h0y  \
# 0              0          a              0              0  0.356595  0.485021
# 1              0          a              0              0  0.567594  0.906298
# 2              0          a              0              1  0.352816  0.484037
# 3              0          a              0              1  0.567833  0.905873
# 4              0          a              0              2  0.351332  0.480660
# ...          ...        ...            ...            ...       ...       ...
# 5001           1          b              1              9  0.405674  0.764709
# 5002           1          b              1             10  0.633578  0.386601
# 5003           1          b              1             10  0.404680  0.765115
# 5004           1          b              1             11  0.633556  0.386977
# 5005           1          b              1             11  0.404066  0.765756
#
#                h0z  ...      cp0z     cp11x     cp11y     cp11z     cp12x  \
# 0    -1.312914e-07  ... -0.181956 -2.098741  0.873798  0.027716 -2.306700
# 1     4.943682e-09  ... -0.181956 -3.480238  0.964271  0.265744 -2.306700
# 2    -1.180915e-07  ... -0.333521 -2.066678  1.008282 -0.080830 -2.165842
# 3     4.337321e-09  ... -0.333521 -3.455541  1.185928  0.076849 -2.165842
# 4    -1.254345e-07  ... -0.233376 -2.168897  0.905824  0.014499 -2.366600
# ...            ...  ...       ...       ...       ...       ...       ...
# 5001  5.895547e-08  ... -0.084159 -2.557804  1.086794  0.216372 -1.526016
# 5002 -1.037258e-07  ... -0.062124 -1.350568  0.798976  0.045304 -1.538694
# 5003  4.365882e-08  ... -0.062124 -2.565837  1.078161  0.218660 -1.538694
# 5004 -1.034930e-07  ...  0.009736 -1.291110  0.718431  0.083880 -1.526755
# 5005  5.479360e-08  ...  0.009736 -2.474521  0.950366  0.295865 -1.526755
#
#          cp12y     cp12z  cp_h_mean_x  cp_h_mean_y  cp_h_mean_z
# 0     1.885125 -0.694826    -2.896234     1.150676    -0.222430
# 1     1.885125 -0.694826    -2.414786     1.221503    -0.128008
# 2     2.062525 -0.801491    -2.825404     1.313214    -0.356977
# 3     2.062525 -0.801491    -2.343657     1.351576    -0.232162
# 4     1.999840 -0.726445    -2.981283     1.221755    -0.257633
# ...        ...       ...          ...          ...          ...
# 5001  1.644848 -0.550490    -1.936456     1.060899    -0.106899
# 5002  1.641183 -0.535136    -1.488300     1.035166     0.027075
# 5003  1.641183 -0.535136    -1.948699     1.025206    -0.083890
# 5004  1.476018 -0.468762    -1.434433     0.942531     0.069260
# 5005  1.476018 -0.468762    -1.886699     0.910612    -0.025058
#
# [5006 rows x 176 columns]

# %%
# After the change of base we are no longer in the orientation of the body
PH2_AH_FRM_p_chest_df = PH2_AH_FRM_p_chest_df.drop(
    columns=sup.pf_p_v123_columns
)

# %% [markdown]
# # Write out data

# %%
# Drop PH1 columns, so to avoid duplicated data
# These columns were only useful to determine the active hand.
PH2_final_df = PH2_AH_FRM_p_chest_df.drop(
    columns=sup.pf_hand_landmark_columns+sup.pf_pose_landmark_columns
)
PH2_final_df
# Out:
#                                                  fileid person_id  cycle_num  \
# 0         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 1         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 2         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 3         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# 4         p01/Ciclo_1_5_Derecha/Ciclo_1_5_Derecha_a.mp4       p01          1
# ...                                                 ...       ...        ...
# 5001  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5002  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5003  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5004  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
# 5005  p11/Ciclo_5_5_Izquierda/Ciclo_5_5_Izquierda_b.mp4       p11          5
#
#       handedness class_name  class_numeric  current_frame  active_hand  \
# 0              0          a              0              0            1
# 1              0          a              0              0            0
# 2              0          a              0              1            1
# 3              0          a              0              1            0
# 4              0          a              0              2            1
# ...          ...        ...            ...            ...          ...
# 5001           1          b              1              9            0
# 5002           1          b              1             10            1
# 5003           1          b              1             10            0
# 5004           1          b              1             11            1
# 5005           1          b              1             11            0
#
#       h_mean_x  h_mean_y  ...      cp0z     cp11x     cp11y     cp11z  \
# 0     0.360239  0.416955  ... -0.181956 -2.098741  0.873798  0.027716
# 1     0.561710  0.987890  ... -0.181956 -3.480238  0.964271  0.265744
# 2     0.358858  0.415220  ... -0.333521 -2.066678  1.008282 -0.080830
# 3     0.561693  0.987804  ... -0.333521 -3.455541  1.185928  0.076849
# 4     0.357507  0.414159  ... -0.233376 -2.168897  0.905824  0.014499
# ...        ...       ...  ...       ...       ...       ...       ...
# 5001  0.427331  0.818829  ... -0.084159 -2.557804  1.086794  0.216372
# 5002  0.631197  0.275317  ... -0.062124 -1.350568  0.798976  0.045304
# 5003  0.426652  0.818555  ... -0.062124 -2.565837  1.078161  0.218660
# 5004  0.631751  0.276256  ...  0.009736 -1.291110  0.718431  0.083880
# 5005  0.426416  0.818708  ...  0.009736 -2.474521  0.950366  0.295865
#
#          cp12x     cp12y     cp12z  cp_h_mean_x  cp_h_mean_y  cp_h_mean_z
# 0    -2.306700  1.885125 -0.694826    -2.896234     1.150676    -0.222430
# 1    -2.306700  1.885125 -0.694826    -2.414786     1.221503    -0.128008
# 2    -2.165842  2.062525 -0.801491    -2.825404     1.313214    -0.356977
# 3    -2.165842  2.062525 -0.801491    -2.343657     1.351576    -0.232162
# 4    -2.366600  1.999840 -0.726445    -2.981283     1.221755    -0.257633
# ...        ...       ...       ...          ...          ...          ...
# 5001 -1.526016  1.644848 -0.550490    -1.936456     1.060899    -0.106899
# 5002 -1.538694  1.641183 -0.535136    -1.488300     1.035166     0.027075
# 5003 -1.538694  1.641183 -0.535136    -1.948699     1.025206    -0.083890
# 5004 -1.526755  1.476018 -0.468762    -1.434433     0.942531     0.069260
# 5005 -1.526755  1.476018 -0.468762    -1.886699     0.910612    -0.025058
#
# [5006 rows x 95 columns]

# %%
print(PH2_final_df.columns.to_list())
# Out:
# ['fileid', 'person_id', 'cycle_num', 'handedness', 'class_name', 'class_numeric', 'current_frame', 'active_hand', 'h_mean_x', 'h_mean_y', 'h_mean_z', 'h_v1x', 'h_v1y', 'h_v1z', 'h_v2x', 'h_v2y', 'h_v2z', 'h_v3x', 'h_v3y', 'h_v3z', 'wh0x', 'wh0y', 'wh0z', 'wh1x', 'wh1y', 'wh1z', 'wh2x', 'wh2y', 'wh2z', 'wh3x', 'wh3y', 'wh3z', 'wh4x', 'wh4y', 'wh4z', 'wh5x', 'wh5y', 'wh5z', 'wh6x', 'wh6y', 'wh6z', 'wh7x', 'wh7y', 'wh7z', 'wh8x', 'wh8y', 'wh8z', 'wh9x', 'wh9y', 'wh9z', 'wh10x', 'wh10y', 'wh10z', 'wh11x', 'wh11y', 'wh11z', 'wh12x', 'wh12y', 'wh12z', 'wh13x', 'wh13y', 'wh13z', 'wh14x', 'wh14y', 'wh14z', 'wh15x', 'wh15y', 'wh15z', 'wh16x', 'wh16y', 'wh16z', 'wh17x', 'wh17y', 'wh17z', 'wh18x', 'wh18y', 'wh18z', 'wh19x', 'wh19y', 'wh19z', 'wh20x', 'wh20y', 'wh20z', 'cp0x', 'cp0y', 'cp0z', 'cp11x', 'cp11y', 'cp11z', 'cp12x', 'cp12y', 'cp12z', 'cp_h_mean_x', 'cp_h_mean_y', 'cp_h_mean_z']

# %%
PH2_final_df.to_csv(sup.PH2_DATA_AH_PF_CSV, index=False)
